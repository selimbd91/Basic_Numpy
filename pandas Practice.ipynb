# %%
import pandas as pd
import numpy as np

import os

print(os.getcwd())

df = pd.read_csv("practice2.txt", delimiter= ",", na_values= ["no values", "not available"], index_col= [4])
df
# df2 = df[(df["industry_code_ANZSIC"] == "A") & (df["value"] >1000)]
# df2.reset_index(inplace=True)
# df2
# Out:
# C:\Users\LENOVO\PycharmProjects\Facebook
#                                                  year industry_code_ANZSIC  \
# variable
# Activity unit                                    2011                    A
# Rolling mean employees                           2011                    A
# Salaries and wages paid                          2011                    A
# Sales, government funding, grants and subsidies  2011                  NaN
# Total income                                     2011                  NaN
# Total expenditure                                2011                  NaN
# Operating profit before tax                      2011                    A
# Total assets                                     2011                    A
# Fixed tangible assets                            2011                    A
# Activity unit                                    2011                    A
# Rolling mean employees                           2011                    A
# ...

# %%
# Out:
#     year industry_code_ANZSIC               industry_name_ANZSIC rme_size_grp  \
# 0   2011                    A  Agriculture, Forestry and Fishing          a_0
# 1   2011                    A  Agriculture, Forestry and Fishing          a_0
# 2   2011                    A  Agriculture, Forestry and Fishing          a_0
# 3   2011            no values  Agriculture, Forestry and Fishing          a_0
# 4   2011                  NaN  Agriculture, Forestry and Fishing          a_0
# 5   2011                  NaN  Agriculture, Forestry and Fishing          a_0
# 6   2011                    A  Agriculture, Forestry and Fishing          a_0
# 7   2011                    A  Agriculture, Forestry and Fishing          a_0
# 8   2011                    A  Agriculture, Forestry and Fishing          a_0
# 9   2011                    A  Agriculture, Forestry and Fishing        b_1-5
# 10  2011                    A  Agriculture, Forestry and Fishing        b_1-5
# ...

# %%
df = pd.read_csv("practice2.txt", delimiter= ",", names= ["year", "industry code", "industry name", "size", "variable", "value", "unit"]
                ,skiprows=[0])
df2 = df.copy()
df2.to_csv("latest_practice.txt", sep= "\t", index= False)

# %%
my_dict = {"name": ["selim", "rahim", "karim"], "age":[20, 22, 34], "country": ["dhaka", "soudi", "comilla"]}
xx = pd.DataFrame(my_dict)
yy = xx.set_index([["a","b","c"]])
yy
# Out:
#     name  age  country
# a  selim   20    dhaka
# b  rahim   22    soudi
# c  karim   34  comilla
