# %%
import pandas as pd
import numpy as np
 
df = pd.read_csv("practice2.txt", delimiter= ",", skiprows= [0,14,12,13,2], names=["year", "type", "industry", "size", "variable", "value", "unit"])
df.set_index([["a","b", "c", "d", "e", "f", "g", "h", "i", "j"]],inplace= True,)
df
# Out:
#    year       type                           industry   size  \
# a  2011          A  Agriculture, Forestry and Fishing    a_0
# b  2011          A  Agriculture, Forestry and Fishing    a_0
# c  2011  no values  Agriculture, Forestry and Fishing    a_0
# d  2011        NaN  Agriculture, Forestry and Fishing    a_0
# e  2011        NaN  Agriculture, Forestry and Fishing    a_0
# f  2011          A  Agriculture, Forestry and Fishing    a_0
# g  2011          A  Agriculture, Forestry and Fishing    a_0
# h  2011          A  Agriculture, Forestry and Fishing    a_0
# i  2011          A  Agriculture, Forestry and Fishing  b_1-5
# j  2011          A  Agriculture, Forestry and Fishing  b_1-5
#
#                                           variable  value               unit
# a                                    Activity unit  46134              COUNT
# b                          Salaries and wages paid    279  DOLLARS(millions)
# ...
